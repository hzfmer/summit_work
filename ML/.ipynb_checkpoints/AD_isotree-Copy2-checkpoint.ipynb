# %% [markdown]
# # Index
# * [Load and inpect data](#Load-and-inpect-data)
# * [Outliers](#Outliers)
#     * [Conversion](#Conversion)
#     * [Time Spend Per Day](#Time-Spend-Per-Day)
# * [Inspect Country's distribution](#Inspect-Country's-distribution)
# * [Visualize data](#Visualize-data)
# * [Cluster](#Cluster)
#     * [Preprocessing](#Preprocessins)
#     * [KMeans](#KMeans)
#     * [MeanShift](#MeanShift)
# * [Anomaly detection](#Anomaly-detection)
#     * [KMeans clustering](#KMeans-Clustering)
#     * [Isolation Tree](#Osilation-Tree)
#     * [Support Vector Machine](#Support-Vector-Machine)
#
# This is a jupyter notebook for the take-home challenge from Tencent NA.
#
# A dateset is provided in a CSV file "topline_matrics.csv".\
# The tasks accomplished are:
# 1. Clustering/prediction models based on the attached dataset.
# 2. Use Anomaly Detection methodologies to detect anomaly from the attached data.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import pickle
import re
matplotlib.rcParams['font.sans-serif'] = ['Source Han Sans TW', 'DejaVu Sans']
matplotlib.rcParams['figure.dpi'] = 400
# %matplotlib inline
import warnings # Ignore too many warnings when plotting
warnings.filterwarnings("ignore")

# Load sklearn libraries
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.cluster import MiniBatchKMeans
from sklearn.cluster import MeanShift
from sklearn.ensemble import IsolationForest
from sklearn.svm import OneClassSVM

# %% [markdown]
# ## Load and inpect data

# %%
# Read data
inputfilename = 'topline_metrics.csv'
df = pd.read_csv(inputfilename)
df.head(3)
# Out:
#          Date      Date.1      Platform            Country        TRU  \
# 0  2018-03-15  2018-03-15  Android(All)  Kazakhstan(哈萨克斯坦)  628852.81
# 1  2018-03-15  2018-03-15           ALL  United States(美国)  633293.54
# 2  2018-03-15  2018-03-15  Android(All)  Kazakhstan(哈萨克斯坦)  628852.81
#
#         DAU     Items    Trans  Items Per Trans  Items per DAU  Conversion  \
# 0  15498.31  43429.11  3428.09            17.58            1.3         2.3
# 1  19939.05  43429.11  3428.09            17.58            1.3         2.3
# 2  15498.31  43429.11  3428.09            17.58            1.3         2.3
#
#    Cash Flow  Return Customer  Time Spend Per Day(seconds)
# 0    4527.01            79.12                        58.18
# 1    4527.01            75.65                        58.87
# 2    4527.01            79.12                        58.18

# %%
# Check if there is any empty cells
df.isnull().sum().sort_values(ascending=False)
# Out:
# Time Spend Per Day(seconds)    0
# Return Customer                0
# Cash Flow                      0
# Conversion                     0
# Items per DAU                  0
# Items Per Trans                0
# Trans                          0
# Items                          0
# DAU                            0
# TRU                            0
# Country                        0
# Platform                       0
# Date.1                         0
# Date                           0
# dtype: int64

# %% [markdown]
# There is no empty items in the dataset, so we don't need to manually fill or drop values.

# %%
# Glance at data
df.describe()
# Out:
#                 TRU           DAU         Items         Trans  \
# count  7.482640e+05  7.482640e+05  7.482640e+05  748264.00000
# mean   7.399568e+05  1.816949e+04  5.089120e+04    3958.49364
# std    6.776595e+05  1.801799e+04  4.610241e+04    3655.62504
# min    6.286478e+05  1.529217e+04  4.342911e+04    3428.09000
# 25%    6.288102e+05  1.529677e+04  4.342911e+04    3428.09000
# 50%    6.314452e+05  1.537393e+04  4.352124e+04    3433.85000
# 75%    6.574735e+05  1.617663e+04  4.466021e+04    3522.53000
# max    2.677675e+07  2.141935e+06  4.387412e+06  434846.58000
#
#        Items Per Trans  Items per DAU     Conversion      Cash Flow  \
# count    748264.000000  748264.000000  748264.000000  748264.000000
# mean         31.569433       1.414330       2.902036    5093.453512
# std          23.629177       1.208879       2.591666    4712.790645
# min          17.580000       1.300000       2.300000    4527.010000
# 25%          17.580000       1.300000       2.300000    4527.010000
# 50%          28.090000       1.320000       2.560000    4532.770000
# 75%          36.080000       1.390000       3.000000    4611.080000
# max        1744.870000     444.240000     232.630000  819825.280000
#
#        Return Customer  Time Spend Per Day(seconds)
# count    748264.000000                748264.000000
# mean         39.795054                   122.605716
# std          24.796009                    43.331318
# min          12.210000                    -9.990000
# 25%          28.660000                    98.950000
# 50%          39.430000                   118.180000
# 75%          48.920000                   139.370000
# max        3912.090000                  1390.060000

# %% [markdown]
# The column names have spaces, which can be annoying some times. The first two columns have the same names originally; the name of countries are mixed of Chinese characters and English letters; the last column has unit in its name, which is redundant when coding. I prefer to re-format them.

# %%
df['Date'].equals(df['Date.1'])
# Out:
# True

# %% [markdown]
# Since the first and the second column are identical, we can just keep one of them.

# %%
# Remove the second column,which is identical with the first column
df.drop('Date.1', axis=1, inplace=True)
df['Date'] = pd.to_datetime(df['Date'])  # Time format

# %%
# Use regex to leave only Chinese characters in Country's name, as some
# countries do not have english name in the data set.
# Keep "Other" countries
df['Country'] = df['Country'].map(lambda x: re.search(r'[\u4e00-\u9fff]+|$', x).group())
df = df.replace('', '其他')

# %%
# Formatting the column names
df.rename(columns={'Time Spend Per Day(seconds)': 'Time Spend Per Day'}, inplace=True)  # Remove unit in the last row's name
df.columns = [c.replace(' ', '_') for c in df.columns]  # Replace space by underscore
df.head(3)
# Out:
#         Date      Platform Country        TRU       DAU     Items    Trans  \
# 0 2018-03-15  Android(All)   哈萨克斯坦  628852.81  15498.31  43429.11  3428.09
# 1 2018-03-15           ALL      美国  633293.54  19939.05  43429.11  3428.09
# 2 2018-03-15  Android(All)   哈萨克斯坦  628852.81  15498.31  43429.11  3428.09
#
#    Items_Per_Trans  Items_per_DAU  Conversion  Cash_Flow  Return_Customer  \
# 0            17.58            1.3         2.3    4527.01            79.12
# 1            17.58            1.3         2.3    4527.01            75.65
# 2            17.58            1.3         2.3    4527.01            79.12
#
#    Time_Spend_Per_Day
# 0               58.18
# 1               58.87
# 2               58.18

# %% [markdown]
# The dataset should now look clearer.

# %% [markdown]
# ### Outliers
#
# There are some obvious abnormal data to be handled, for example the maximum conversion rate is over 100% and the minimum time spent per day is negative. We should first get rid of such data outliers.

# %% [markdown]
# #### Conversion

# %%
# Conversion should be smaller than 100
# Time Spent per day should be non-negative
df.loc[(df.Conversion>100) & (df.Time_Spend_Per_Day < 0), :]
# Out:
#              Date  Platform Country        TRU       DAU     Items    Trans  \
# 524347 2019-08-07  IOS(All)     图瓦卢  628647.81  15293.32  43440.62  3429.24
# 695006 2020-01-19  IOS(All)    基里巴斯  628647.81  15293.32  43440.62  3429.24
# 695195 2020-01-19  IOS(All)    基里巴斯  628647.81  15293.32  43440.62  3429.24
#
#         Items_Per_Trans  Items_per_DAU  Conversion  Cash_Flow  \
# 524347            29.07          12.79      117.46    4528.17
# 695006            29.08          12.80      117.46    4528.17
# 695195            29.08          12.80      117.46    4528.17
#
#         Return_Customer  Time_Spend_Per_Day
# 524347            12.21               -6.54
# 695006            12.21               -8.27
# 695195            12.21               -8.27

# %% [markdown]
# There are three rows with both abnormal **Conversion** and **Time_Spend_Per_Day**.

# %%
# Find abnormals
df.loc[(df.Conversion>100), :]
# Out:
#              Date      Platform  Country        TRU       DAU     Items  \
# 84426  2018-06-08           ALL     诺福克岛  628647.81  15292.17  43432.56
# 132352 2018-07-26           ALL      马恩岛  628647.81  15292.17  43444.08
# 132867 2018-07-26           ALL      马恩岛  628647.81  15292.17  43444.08
# 132993 2018-07-26           ALL      马恩岛  628647.81  15292.17  43444.08
# 161847 2018-08-23  Android(All)  瓦利斯和富图纳  628647.81  15292.17  43486.69
# ...           ...           ...      ...        ...       ...       ...
# 739584 2020-03-01  Android(All)      根西岛  628647.81  15292.17  43436.02
# 742101 2020-03-04  Android(All)      根西岛  628647.81  15292.17  43430.26
# 742213 2020-03-04  Android(All)       朝鲜  628647.81  15292.17  43434.87
# 742362 2020-03-04  Android(All)      根西岛  628647.81  15292.17  43430.26
# 742816 2020-03-04  Android(All)       朝鲜  628647.81  15292.17  43434.87
#
#           Trans  Items_Per_Trans  Items_per_DAU  Conversion  Cash_Flow  \
# 84426   3429.24            21.47           5.19      117.46    4527.01
# 132352  3429.24            32.94          16.66      117.46    4528.17
# 132867  3429.24            32.94          16.66      117.46    4528.17
# 132993  3429.24            32.94          16.66      117.46    4528.17
# 161847  3429.24            75.14          58.86      117.46    4531.62
# ...         ...              ...            ...         ...        ...
# 739584  3429.24            24.33           8.05      117.46    4527.01
# 742101  3429.24            18.33           2.05      117.46    4527.01
# 742213  3429.24            23.20           6.92      117.46    4527.01
# 742362  3429.24            18.33           2.05      117.46    4527.01
# 742816  3429.24            23.20           6.92      117.46    4527.01
#
#         Return_Customer  Time_Spend_Per_Day
# 84426             12.21               64.98
# 132352            12.21               69.47
# 132867            12.21               69.47
# 132993            12.21               69.47
# 161847            12.21              712.55
# ...                 ...                 ...
# 739584            12.21               25.48
# 742101            12.21               84.67
# 742213            12.21              272.50
# 742362            12.21               84.67
# 742816            12.21              272.50
#
# [242 rows x 13 columns]

# %% [markdown]
# There are 242 outliers in terms of conversion rate, which for some reason all share some identical features, including **TRU**, **DAU**, **Trans**, **Conversion** and **Return Custom**.

# %%
df.loc[df.Conversion<=100, :].describe()
# Out:
#                 TRU           DAU         Items          Trans  \
# count  7.480220e+05  7.480220e+05  7.480220e+05  748022.000000
# mean   7.399928e+05  1.817042e+04  5.089360e+04    3958.664854
# std    6.777662e+05  1.802083e+04  4.610967e+04    3656.203931
# min    6.286478e+05  1.529217e+04  4.342911e+04    3428.090000
# 25%    6.288113e+05  1.529677e+04  4.342911e+04    3428.090000
# 50%    6.314521e+05  1.537393e+04  4.352124e+04    3433.850000
# 75%    6.574962e+05  1.617778e+04  4.466137e+04    3522.530000
# max    2.677675e+07  2.141935e+06  4.387412e+06  434846.580000
#
#        Items_Per_Trans  Items_per_DAU     Conversion      Cash_Flow  \
# count    748022.000000  748022.000000  748022.000000  748022.000000
# mean         31.565888       1.406276       2.864359    5093.636245
# std          23.610861       0.505054       1.503238    4713.541972
# min          17.580000       1.300000       2.300000    4527.010000
# 25%          17.580000       1.300000       2.300000    4527.010000
# 50%          28.090000       1.320000       2.560000    4532.770000
# 75%          36.080000       1.390000       3.000000    4611.080000
# max        1744.870000      73.470000      59.880000  819825.280000
#
#        Return_Customer  Time_Spend_Per_Day
# count    748022.000000       748022.000000
# mean         39.803978          122.572361
# std          24.795055           43.166742
# min          12.210000           -9.990000
# 25%          28.660000           98.950000
# 50%          39.430000          118.180000
# 75%          48.920000          139.370000
# max        3912.090000         1390.060000

# %% [markdown]
# Wihtout the outliers of **Conversion**, there are 748022 rows of data with the range of **Conversion** from 2.3 to 59.88, which is more reasonable, though the maximum value is significantly larger than even the 75% percentile.
#
# The outliers only account for 0.03234% of the total dataset and they all come from small countres that are less populated and less developed. We have a very good reason to surmise that the data sources in these countries are not pretty reliable, therefore we should ignore these data.

# %%
# Remove abnormals
df = df.loc[df.Conversion<=100, :]

# %% [markdown]
# #### Time Spend Per Day

# %%
df.loc[df.Time_Spend_Per_Day<0, :]
# Out:
#              Date      Platform  Country        TRU       DAU     Items  \
# 93     2018-03-15           ALL      巴哈马  628647.81  15293.32  43429.11
# 158    2018-03-15  Android(All)      巴哈马  628647.81  15293.32  43429.11
# 160    2018-03-15           ALL      安道尔  628648.96  15294.47  43429.11
# 169    2018-03-15  Android(All)      巴哈马  628647.81  15293.32  43429.11
# 181    2018-03-15           ALL     格林纳达  628647.81  15293.32  43429.11
# ...           ...           ...      ...        ...       ...       ...
# 747030 2020-03-08      IOS(All)  英属印度洋领地  628647.81  15292.17  43429.11
# 747117 2020-03-08      IOS(All)  英属印度洋领地  628647.81  15292.17  43429.11
# 747475 2020-03-09      IOS(All)     基里巴斯  628647.81  15292.17  43429.11
# 747810 2020-03-09      IOS(All)     基里巴斯  628647.81  15292.17  43429.11
# 748175 2020-03-09      IOS(All)     基里巴斯  628647.81  15292.17  43429.11
#
#           Trans  Items_Per_Trans  Items_per_DAU  Conversion  Cash_Flow  \
# 93      3428.09            17.58            1.3         2.3    4527.01
# 158     3428.09            17.58            1.3         2.3    4527.01
# 160     3428.09            17.58            1.3         2.3    4527.01
# 169     3428.09            17.58            1.3         2.3    4527.01
# 181     3428.09            17.58            1.3         2.3    4527.01
# ...         ...              ...            ...         ...        ...
# 747030  3428.09            17.58            1.3         2.3    4527.01
# 747117  3428.09            17.58            1.3         2.3    4527.01
# 747475  3428.09            17.58            1.3         2.3    4527.01
# 747810  3428.09            17.58            1.3         2.3    4527.01
# 748175  3428.09            17.58            1.3         2.3    4527.01
#
#         Return_Customer  Time_Spend_Per_Day
# 93                12.21               -9.99
# 158               12.21               -9.99
# 160               12.21               -2.74
# 169               12.21               -9.99
# 181               12.21               -8.50
# ...                 ...                 ...
# 747030            12.21               -1.93
# 747117            12.21               -1.93
# 747475            12.21               -9.19
# 747810            12.21               -9.19
# 748175            12.21               -9.19
#
# [1032 rows x 13 columns]

# %% [markdown]
# Just like what we saw above, the rest 1032 (0.138%) outliers with negative **Time_Spend_Per_Day** somehow share identical information in other columns. Again the data source is probably not reliable due to the same reason, and we choose to remove them.

# %%
df = df.loc[df.Time_Spend_Per_Day>=0, :]
df.describe()
# Out:
#                 TRU           DAU         Items          Trans  \
# count  7.469900e+05  7.469900e+05  7.469900e+05  746990.000000
# mean   7.401413e+05  1.817318e+04  5.090383e+04    3959.386961
# std    6.782207e+05  1.802984e+04  4.614068e+04    3658.675812
# min    6.286478e+05  1.529217e+04  4.342911e+04    3428.090000
# 25%    6.288125e+05  1.529792e+04  4.342911e+04    3428.090000
# 50%    6.314843e+05  1.537508e+04  4.352239e+04    3433.850000
# 75%    6.575748e+05  1.618008e+04  4.466712e+04    3522.530000
# max    2.677675e+07  2.141935e+06  4.387412e+06  434846.580000
#
#        Items_Per_Trans  Items_per_DAU     Conversion      Cash_Flow  \
# count    746990.000000  746990.000000  746990.000000  746990.000000
# mean         31.584992       1.406380       2.864980    5094.417427
# std          23.621483       0.504734       1.501235    4716.749912
# min          17.580000       1.300000       2.300000    4527.010000
# 25%          17.580000       1.300000       2.300000    4527.010000
# 50%          28.100000       1.320000       2.570000    4532.770000
# 75%          36.110000       1.390000       3.000000    4611.080000
# max        1744.870000      73.470000      59.880000  819825.280000
#
#        Return_Customer  Time_Spend_Per_Day
# count    746990.000000       746990.000000
# mean         39.839095          122.749071
# std          24.788552           42.933628
# min          12.210000            0.030000
# 25%          28.710000           98.950000
# 50%          39.450000          118.300000
# 75%          48.940000          139.490000
# max        3912.090000         1390.060000

# %% [markdown]
# ## Visualize data

# %%
# Covariance between columns, except Date / Platform / Country
corrmat = df.corr()
plt.subplots(figsize=(12,9))
sns.heatmap(df.corr(), annot=True, fmt='.1f', linewidths=.5, vmax=0.9, square=True)
#plt.show()

# %%
df.Cash_Flow.plot(kind='line', color='g', label='Cash Flow')

# %%
df.Cash_Flow.plot(kind='hist', label='Cash Flow')

# %%
figure=plt.figure()
sns.pairplot(x_vars=['Trans','Items_Per_Trans','Items','Time_Spend_Per_Day'],y_vars=['Items_Per_Trans','Items','Time_Spend_Per_Day','Trans'],data=df,dropna=True)
plt.show()

# %%
df.Platform.value_counts().plot(kind="bar")

# %%
sns.stripplot(x="Platform", y="Trans", data=df)

# %%
for i in range(7):
    print(np.mean(df.DAU[i::7]))
# Out:
# 18187.5222686104
# 18152.062532776457
# 18169.931400955804
# 18161.977182819275
# 18120.500656247914
# 18175.728073432623
# 18244.527017956883

# %%
plt.scatter(df.Date, df.Trans)

# %%
# Sum of Transactions at each country
country_trans = pd.crosstab(df.Country, df.Trans)
country_trans_total = country_trans.sum(axis=1).sort_values(ascending=False)
sns.barplot(y = country_trans_total.index, x = country_trans_total.values, orient='h')
plt.ylabel('Country')
plt.xlabel('Trans')
plt.yaxis([])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-183-4e74e22ac987> in <module>
#       1 # Sum of Transactions at each country
# ----> 2 country_trans = pd.crosstab(df.Country, df.Trans)
#       3 country_trans_total = country_trans.sum(axis=1).sort_values(ascending=False)
#       4 sns.barplot(y = country_trans_total.index, x = country_trans_total.values, orient='h')
#       5 plt.ylabel('Country')
#
# ~/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Country'

# %%
sns.FacetGrid(df, hue='Platform', size=6) \
    .map(plt.scatter, 'Trans', 'Items') \
    .add_legend()
#'Items_Per_Trans', 'Items_per_DAU'

# %%
df_back = df
df_back.head(3)
# Out:
#         Date      Platform Country        TRU       DAU     Items    Trans  \
# 0 2018-03-15  Android(All)   哈萨克斯坦  628852.81  15498.31  43429.11  3428.09
# 1 2018-03-15           ALL      美国  633293.54  19939.05  43429.11  3428.09
# 2 2018-03-15  Android(All)   哈萨克斯坦  628852.81  15498.31  43429.11  3428.09
#
#    Items_Per_Trans  Items_per_DAU  Conversion  Cash_Flow  Return_Customer  \
# 0            17.58            1.3         2.3    4527.01            79.12
# 1            17.58            1.3         2.3    4527.01            75.65
# 2            17.58            1.3         2.3    4527.01            79.12
#
#    Time_Spend_Per_Day
# 0               58.18
# 1               58.87
# 2               58.18

# %% [markdown]
# ## Cluster

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
# Load library
from sklearn.cluster import KMeans
from sklearn.cluster import MiniBatchKMeans
from sklearn.cluster import MeanShift
from sklearn.covariance import EllipticEnvelope
#from pyemma import msm
from sklearn.ensemble import IsolationForest
from sklearn.svm import OneClassSVM

# %% [markdown]
# ### Preprocessing

# %%
# One-hot encoding "Platform" and "Country"
# Delete the redundant "ALL" platform and "Other" country
df = pd.get_dummies(df, columns=['Platform', 'Country'], prefix="", prefix_sep="")
del df['ALL']
del df['其他']

# Add a column of data converted to integers, for easier plotting
df['Date_Int'] = df.Date.astype(np.int64)

# %%
# Take useful features and standardize them.
# The Country feature is discarded, since by removing abnormals the 
# rest countries are assumed to be reliable source input.

scaled_data = StandardScaler().fit_transform(df.iloc[:, 1:13])
data_featured = pd.DataFrame(scaled_data)
data_featured.describe()
# Out:
#                  0             1             2             3             4   \
# count  7.469900e+05  7.469900e+05  7.469900e+05  7.469900e+05  7.469900e+05
# mean  -3.673538e-15  1.194569e-14 -1.850348e-14  8.590359e-14  2.865884e-13
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -1.643913e-01 -1.597912e-01 -1.619986e-01 -1.452157e-01 -5.928926e-01
# 25%   -1.641485e-01 -1.594723e-01 -1.619986e-01 -1.452157e-01 -5.928926e-01
# 50%   -1.602090e-01 -1.551927e-01 -1.599769e-01 -1.436414e-01 -1.475350e-01
# 75%   -1.217400e-01 -1.105445e-01 -1.351674e-01 -1.194031e-01  1.915634e-01
# max    3.838961e+01  1.177916e+02  9.398454e+01  1.177714e+02  7.253085e+01
#
#                  5             6             7             8             9   \
# count  7.469900e+05  7.469900e+05  7.469900e+05  7.469900e+05  7.469900e+05
# mean  -2.094402e-13  2.961263e-13 -1.480976e-13  9.212210e-14 -9.913903e-15
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -2.107655e-01 -3.763438e-01 -1.202964e-01 -1.114592e+00 -2.858346e+00
# 25%   -2.107655e-01 -3.763438e-01 -1.202964e-01 -4.489614e-01 -5.543228e-01
# 50%   -1.711406e-01 -1.964917e-01 -1.190752e-01 -1.569659e-02 -1.036268e-01
# 75%   -3.245368e-02  8.993943e-02 -1.024726e-01  3.671417e-01  3.899261e-01
# max    1.427755e+02  3.797878e+01  1.727315e+02  1.562114e+02  2.951793e+01
#
#                  10            11
# count  7.469900e+05  7.469900e+05
# mean   9.096070e-15  2.952321e-15
# std    1.000001e+00  1.000001e+00
# min   -7.096521e-01 -6.995172e-01
# 25%   -7.096521e-01 -6.995172e-01
# 50%   -7.096521e-01 -6.995172e-01
# 75%    1.409141e+00  1.429557e+00
# max    1.409141e+00  1.429557e+00

# %%
#Calculating Eigenvecors and eigenvalues of Covariance matrix

mean_vec = np.mean(data_featured, axis=0)
cov_mat = np.cov(data_featured.T)
eig_vals, eig_vecs = np.linalg.eig(cov_mat)

# Create a list of (eigenvalue, eigenvector) tuples, sort by engenvalues
eig_pairs = [ (np.abs(eig_vals[i]),eig_vecs[:,i]) for i in range(len(eig_vals))]
eig_pairs.sort(key = lambda x: x[0], reverse= True)

# Calculation of Explained Variance from the eigenvalues
tot = sum(eig_vals)
var_exp = [(i / tot) * 100 for i in sorted(eig_vals, reverse=True)] # Individual explained variance
cum_var_exp = np.cumsum(var_exp) # Cumulative explained variance

# Visualize explained variance
plt.figure(figsize=(10, 5), dpi=400)
plt.bar(range(len(var_exp)), var_exp, alpha=0.3, align='center', label='individual explained variance', color = 'g')
plt.step(range(len(cum_var_exp)), cum_var_exp, where='mid',label='cumulative explained variance')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal components')
plt.yticks(range(0, 100, 10))
plt.legend(loc='best')
plt.grid('on')
plt.show()

# %% [markdown]
# We see the first six components explain about 80% of the variance and first eight explain 90%. We can set number of components to 8.

# %%
# Reduced to 8 important components
n_comp = 8
pca = PCA(n_components=n_comp)
data_tmp = pca.fit_transform(data_featured)
# Standardize the 8 features
scaled_data = StandardScaler().fit_transform(data_tmp)
data_PCA = pd.DataFrame(scaled_data)
data_PCA.head()

# Add principle components
df.index = data_PCA.index
for i in range(n_comp):
    df[f'PC_{i}'] = data_PCA[i]

# %% [markdown]
# ### KMeans

# %%
# Use elbow curve to determine number of clusters

n_cluster = range(1, 30)  # at most 30 clusters
models = []
for i in n_cluster:
    models.append(MiniBatchKMeans(n_clusters=i, batch_size=64).fit(data_featured))
scores = [models[i].score(data_featured) for i in range(len(models))]

# Visualize the elbow curve to pick number of clusters
fig, ax = plt.subplots(figsize=(10,6))
ax.plot(n_cluster, scores)
ax.set(xlabel='Number of Clusters', ylabel='Score', title='Elbow Curve')
# Out:
# [Text(0, 0.5, 'Score'),
#  Text(0.5, 0, 'Number of Clusters'),
#  Text(0.5, 1.0, 'Elbow Curve')]

# %% [markdown]
# Thr curve levels off after about 20 clusters, implying adding more clusters will not explain much more of the variance in our relevant variables.

# %%
# Cluster using Kmeans

# Train the kmeans model with 20 clusters using MiniBatchKMeans to speed up
cluster_kmeans = MiniBatchKMeans(n_clusters=20, batch_size=64).fit(data)

# Predict cluster numbers
df['cluster_kmeans'] = cluster_kmeans.predict(data_PCA)

# Count of each cluster
print("Cluster", "Count")
df['cluster_kmeans'].value_counts()
# Out:
# Cluster Count
# 5     119864
# 2     113041
# 0      79333
# 11     70354
# 12     66926
# 16     61252
# 1      53408
# 17     39345
# 10     38428
# 18     29117
# 15     16007
# 6      13076
# 19     12576
# 9      12160
# 8       6963
# 14      5884
# 13      3644
# 7       3199
# 3       1630
# 4        783
# Name: cluster_kmeans, dtype: int64

# %% [markdown]
# ### MeanShift

# %%
# Cluster using MeanShift

# Create meanshift object
cluster = MeanShift(n_jobs=-1)

# Train model
cluster_meanshift = cluster.fit(data_PCA)

# Save the model
pickle.dump(cluster_kmeans, open('cluster_kmeans.pickle', 'wb'), protocol=pickle.HIGHEST_PROTOCOL)

# Predict
df['cluster_meanshift'] = cluster_meanshift.predict(data_PCA)

# Count of each cluster
print("Cluster", "Count")
df['cluster_meanshift'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-92-f7da410accd2> in <module>
#      13
#      14 # Train model
# ---> 15 model = cluster.fit(data)
#      16 df['cluster'] = model.predict(data)
#      17 df.index = data.index
#
# ~/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/sklearn/cluster/_mean_shift.py in fit(self, X, y)
#     371         bandwidth = self.bandwidth
#     372         if bandwidth is None:
# --> 373             bandwidth = estimate_bandwidth(X, n_jobs=self.n_jobs)
#     374         elif bandwidth <= 0:
#     375             raise ValueError("bandwidth needs to be greater than zero or None,"
#
# ~/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/sklearn/cluster/_mean_shift.py in estimate_bandwidth(X, quantile, n_samples, random_state, n_jobs)
#      78     bandwidth = 0.
#      79     for batch in gen_batches(len(X), 500):
# ---> 80         d, _ = nbrs.kneighbors(X[batch, :], return_distance=True)
#      81         bandwidth += np.max(d, axis=1).sum()
#      82
#
# ~/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     662                 delayed_query(
#     663                     self._tree, X[s], n_neighbors, return_distance)
# --> 664                 for s in gen_even_slices(X.shape[0], n_jobs)
#     665             )
#     666         else:
#
# ~/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1015
#    1016             with self._backend.retrieval_context():
# -> 1017                 self.retrieve()
#    1018             # Make sure that we get a last message telling us we are done
#    1019             elapsed_time = time.time() - self._start_time
#
# ~/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in retrieve(self)
#     907             try:
#     908                 if getattr(self._backend, 'supports_timeout', False):
# --> 909                     self._output.extend(job.get(timeout=self.timeout))
#     910                 else:
#     911                     self._output.extend(job.get())
#
# ~/file_back/programs/rhea/anaconda3/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~/file_back/programs/rhea/anaconda3/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# ~/file_back/programs/rhea/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/file_back/programs/rhea/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Anomaly detection

# %% [markdown]
# Contamination depicts the proportion proportion of outliers in the dataset. This value varies for different case. Here it is set to be 0.005 / 0.5% below, which is in the same scale of the abnormals removed above.

# %%
contamination = 0.005  # Assume 0.5% anomaly

def plot_anomaly(col_anomaly, metric):
    """Plot anomaly in terms of metric
    
    Parameters
    ----------
    col_anomaly : str
        The column recording if anomaly or not
    metric : str
        The metric relevant to the shown anomaly 
    """
    fig, ax = plt.subplots(dpi=400)
    anomaly = df.loc[df[col_anomaly] == -1, ['Date_Int', metric]]  # anomaly

    ax.plot(df['Date_Int'], df[metric], color='blue', label='Inlier')
    ax.scatter(anomaly['Date_Int'],anomaly[metric], color='red',
               label='Outlier')
    plt.xlabel('Date Time Integer')
    plt.ylabel(metric)
    plt.legend()
    plt.show()
    return

# %% [markdown]
# ### KMeans clustering
#
# After being clustered, normal data will belong to larger clusters while anomalies will not belong to any clusters or belong to small clusters.

# %%
# Compute distance between each point and its nearest centroid
def get_distance_by_point(data, model):
    distance = np.zeros(len(data))
    for i in range(len(data)):
        Xa = np.array(data.loc[i])
        Xb = model.cluster_centers_[model.labels_[i] - 1]
        distance[i] = np.linalg.norm(Xa - Xb)
    return pd.Series(distance)

# Points with the largest distances are considered anomalies
distance = get_distance_by_point(data_PCA, cluster_kmeans)
n_outliers = int(contamination * len(distance))
threshold = distance.nlargest(n_outliers).min()

# The column "anomaly_kmeans" contains the anomaly result of the above
# method (0:normal, 1:anomaly) 
df['anomaly_KMeans'] = -(distance >= threshold).astype(int)

# Visulize the outliers in terms of the metric
metric = 'Conversion'
plot_anomaly('anomaly_KMeans', metric)

# %% [markdown]
# ### Isolation Tree
#
# The IsolationForest "isolates" observations by randomly selecting a feature and then randomly selecting a split value between the maximum and minimum values of the selected feature.
#
# This path length, averaged over a forest of such random trees, is a measure of normality and our decision function.
#
# Random partitioning produces noticeable shorter paths for anomalies. Hence, when a forest of random trees collectively produce shorter path lengths for particular samples, they are highly likely to be anomalies.

# %%
# train isolation forest
AD_IF =  IsolationForest(contamination=contamination, n_jobs=-1)
AD_IF.fit(data_PCA)

# Adding a column marking the outliers detected using isolation forest
df['anomaly_IF'] = pd.Series(AD_IF.predict(data_PCA))

# Visulize the outliers in terms of the metric
metric = 'DAU'
plot_anomaly('anomaly_IF', metric)

# %% [markdown]
# ### Support Vector Machine
#
# OneclasSVM can be used do identify anomalies with unsupervised learning.

# %%
# train Oneclass SVM
AD_SVM = OneClassSVM(nu=contamination, kernel="rbf", gamma=0.01)
AD_SVM.fit(data_PCA)

# Adding a column marking the outliers detected using Oneclass SVM
df['anomaly_SVM'] = pd.Series(AD_SVM.predict(data_PCA))

# Visulize the outliers
metric = 'Trans'
plot_anomaly('anomaly_SVM', metric)

# %% [markdown]
# ### KNN

# %%
# Use a toolkit for detecting anomalies

# Train the KNN detector
from pyod.models.knn import KNN
clf = KNN(contamination=contamination, n_jobs=-1)
clf.fit(data_PCA)

# get outlier scores
KNN_scores = clf.decision_scores_  # raw outlier scores
KNN_pred = clf.labels_  # outlier labels (0: inlier; 1: outlier)
df['anomaly_KNN'] = pd.Series(KNN_pred)

# %%
# Visualize anomalies

item = 'Cash_Flow'
df['Date_Int'] = df.Date.astype(np.int64)
fig, ax = plt.subplots()
anom_KNN = df.loc[df['anomaly_KNN'] == 1, ['Date_Int', item]]  # anomaly

ax.plot(df['Date_Int'], df[item], color='blue', label='Normal')
ax.scatter(anom_KNN['Date_Int'],anom_KNN[item], color='red', label='Anomaly_KNN')
plt.xlabel('Date Time Integer')
plt.ylabel(item)
plt.legend()
plt.show()

# %%
from pyod.models.iforest import IForest

model = IForest(contamination=contamination, n_jobs=-1)
model.fit(data_PCA)

# get outlier scores
IF_scores = model.decision_scores_  # raw outlier scores
IF_pred = model.labels_  # outlier labels (0: inlier; 1: outlier)
df['anomaly_IF'] = (IF_pred == 1).astype(int)

# %%
# Visualize anomalies

item = 'Conversion'
anom_IF = df.loc[df['anomaly_IF'] == 1, ['Date_Int', item]]  # anomaly

fig, ax = plt.subplots()
ax.plot(df['Date_Int'], df[item], color='blue', label='Normal')
ax.scatter(anom_IF['Date_Int'],anom_IF[item], color='red', label='Anomaly_IF')
plt.xlabel('Date Time Integer')
plt.ylabel(item)
plt.legend()
plt.show()

# %%
from sklearn.model_selection import train_test_split
Xtrain,Xtest = train_test_split(df,test_size=0.333)
Xtrain.head()
# Out:
#              Date         TRU       DAU      Items     Trans  Items_Per_Trans  \
# 542409 2019-08-27  3780362.13  52553.61  627855.01  22464.77            52.93
# 120442 2018-07-14   628707.70  15295.62   43429.11   3428.09            17.58
# 44346  2018-04-30   722342.11  20984.74   46303.61   3809.29            26.26
# 617440 2019-11-07   629567.98  15302.53   43480.93   3433.85            27.92
# 465593 2019-06-13   642033.37  15534.01   43579.97   3443.06            29.23
#
#         Items_per_DAU  Conversion  Cash_Flow  Return_Customer  ...      PC_3  \
# 542409           1.52        2.99   14489.89            40.88  ... -0.772739
# 120442           1.30        2.30    4527.01            50.59  ...  0.701350
# 44346            1.33        2.77    4651.39            30.97  ... -0.983665
# 617440           1.37        3.02    4535.08            63.38  ...  0.603514
# 465593           1.31        2.42    4540.83            37.43  ... -0.250574
#
#             PC_4      PC_5      PC_6      PC_7  cluster_kmeans  anomaly_KNN  \
# 542409 -2.050241  0.931723 -0.585422  1.040248               8            1
# 120442 -0.493066 -0.958054  0.034116  0.758978              11            0
# 44346   0.638238  0.988952  0.543899  0.620885              12            0
# 617440 -0.115238  0.067987  0.722934  0.688261              11            0
# 465593  0.105594  0.307277 -0.006844 -1.433121               5            0
#
#         anomaly_kmeans             Date_Int  anomaly_IF
# 542409               0  1566864000000000000           1
# 120442               0  1531526400000000000           0
# 44346                0  1525046400000000000           0
# 617440               0  1573084800000000000           0
# 465593               0  1560384000000000000           0
#
# [5 rows x 263 columns]

# %%
dfm = data_PCA.melt(var_name='columns')
g = sns.FacetGrid(dfm, col='columns')
g = (g.map(sns.distplot, 'value'))

# %% [markdown]
# ## Summary

# %% [markdown]
# There are two clustering models provided:\
# [`cluster_KMeans`](#KMeans), [`cluster_MeanShift`](#MeanShift)
#
# There are three anomaly detection results provided in the DataFrame `df`:\
# **"anomaly_KMeans"**, **"anomaly_IF"**, **"anomaly_SVM"**
#
# The first one comes from the clustering model [`cluster_KMeans`](#KMeans-clustering), the sesond one is generated by an Isolation Forest model [`AD_IT`](#Isolation-Tree), and the last one is from a SVM model [`AD_SVM`](#Support-Vector-Mahine).
#
#
# Since the anomaly detections implemented here are unsupervised learning. After building the models, we have no idea how well it is doing. Hence, the results of those methods need to be tested in the field.
