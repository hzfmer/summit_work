# %%
import numpy as np
from pathlib import Path
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from obspy.signal.konnoohmachismoothing import calculate_smoothing_matrix
from obspy.signal.konnoohmachismoothing import apply_smoothing_matrix
from obspy.signal.konnoohmachismoothing import konno_ohmachi_smoothing

import awp_processing
#plt.style.use('seaborn')
sns.set(context='paper', style='whitegrid', font_scale=1, rc={"xtick.bottom" : True, "ytick.left" : True})
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def adjust_prop_1d(bore_profile, bore_depth, dh, data, bedrock_depth):
    data_out = data.copy()
    for k in range(len(data)):      
        depth = np.searchsorted(bore_depth, k * dh)
        if k * dh >= bedrock_depth:
            depth = max(2, depth)
        data_out[k] = bore_profile[depth]  
    return data_out

def adjust_prop_3d(bore_profile, bore_depth, dh, data, bedrock_depth):
    z, y, x = data.shape
    data_out = data.copy()
    for i in range(x):
        for j in range(y):
            data_out[:, j, i] = adjust_prop_1d(bore_profile, bore_depth,
                                dh, data[:, j, i], bedrock_depth[j, i])
    return data_out

# %%
def estimateRhofromVs(vs):
    N = len(vs)
    rho = np.zeros(N)
    for i in range(N):
        if vs[i] <= 333:
            rho[i] = 2000 + 190 * (vs[i] - 166.5) / 333
        elif vs[i] < 560:
            rho[i] = 2350
        elif vs[i] < 640:
            rho[i] = 2450
        else:
            rho[i] = 2750
    return rho


def estimateQfromVs(vs):
    N = len(vs)
    q = np.zeros(N)
    for i in range(N):
        if vs[i] <= 1000:
            q[i] = 0.06 * vs[i]
        elif vs[i] < 2000:
            q[i] = 0.04 * vs[i]
        else:
            q[i] = 0.16 * vs[i]
    return q

# %%
def SH1D(vs, h, f, theta=0, qs=[], rho=[]):
    """Compute SH1D
    Input:
        vs ([float]): 1D array (N) listing vs in each layer, beginning with the uppermost
        h ([float]): 1D array (N-1) of thickness of each layer
        f ([float]): frequency range
        theta (float): incident angle (0-90), 0-vertical
        qs ([float]): Attenuation
        rho ([float]): density
    """
    if not len(qs):
        qs = estimateQfromVs(vs)
    # qs = [0.05 * i for i in vs]
    #qs = [1e14 for i in vs]
    if not len(rho):
        rho = estimateRhofromVs(vs)
    N = len(vs)
    theta = np.radians(theta)
    ga = np.ones(N) - 0.5j * np.ones(N) / qs
    p = np.sin(theta) / vs[-1]
    eta = ((np.ones(N - 1) / (vs[:-1] * ga[:-1]) ** 2) - p ** 2 * np.ones(N - 1)) ** 0.5
    Im = rho * vs * ga
    r = (Im[1:] - Im[:-1]) / (Im[1:] + Im[:-1])
    t = 2 * Im[1:] / (Im[0:-1] + Im[1:])
    tau = eta * h
    factor = 1
    S11, S22, S12, S21 = 1, 1, 0, 0
    for k in range(N - 1):
        factor = factor * t[k]
        A11 = np.exp(-1j * 2 * np.pi * tau[k] * f)
        A12 = r[k] * np.exp(1j * 2 * np.pi * tau[k] * f)
        A21 = r[k] * np.exp(-1j * 2 * np.pi * tau[k] * f)
        A22 = np.exp(1j * 2 * np.pi * tau[k] * f)
        Stmp11 = A11 * S11 + A12 * S21
        Stmp21 = A21 * S11 + A22 * S21
        Stmp12 = A11 * S12 + A12 * S22
        Stmp22 = A21 * S12 + A22 * S22
        S11 = Stmp11
        S12 = Stmp12
        S21 = Stmp21
        S22 = Stmp22
    amp = np.abs(factor * np.ones(len(f)) / (S11 + S12))
    return amp

# %%
C = awp_processing.analyze.Scenario(model="toy")
fv = C.comp_spec(40, 40, 0, highf=12)
# Out:
# ix=0, iy=1, iz=0
# 8000

# %%
def comp_TTF(C, ix, iy, iz, highf, smoother=[]):
    """Compute TTF using horizontal velocity components
    Input:
        C (class): awp_scenario
        ix, iy, iz (int): site location index, 1-indexed
        
    11.2 Hz exactly
    """
    fv_top = C.comp_spec(ix, iy, 1, highf=highf)
    fv_bot = C.comp_spec(ix, iy, iz, highf=highf)
    fa_top = np.sqrt(fv_top.x ** 2 + fv_top.y ** 2)
    fa_bot = np.sqrt(fv_bot.x ** 2 + fv_bot.y ** 2)
    if not len(smoother):
        smoother = calculate_smoothing_matrix(fv_top, normalize=True)
    ttf = apply_smoothing_matrix(fa_top / fa_bot, smoother, 1)
    f = fv_top['f']
    return np.rec.fromarrays([ttf, f], names='ttf, f')

# %%
it = 1000
s = C.read_slice(it, ix=20, iy=0, iz=0)
plt.imshow(s)
# Out:
# [autoreload of numpy.core.multiarray failed: Traceback (most recent call last):
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/numpy/core/multiarray.py", line 78, in <module>
#     def empty_like(prototype, dtype=None, order=None, subok=None, shape=None):
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/numpy/core/overrides.py", line 186, in decorator
#     if module is not None:
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/numpy/core/overrides.py", line 150, in decorator
#     implementation.__module__ = module
# RuntimeError: empty_like method already has a docstring
# ]
# [autoreload of numpy.core.overrides failed: Traceback (most recent call last):
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/numpy/core/overrides.py", line 47, in <module>
#     """)
# RuntimeError: implement_array_function method already has a docstring
# ]
# [autoreload of numpy.core.numeric failed: Traceback (most recent call last):
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py", line 12, in <module>
#     from numpy.compat import pickle, basestring
# ImportError: cannot import name 'pickle' from 'numpy.compat' (/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/numpy/compat/__init__.py)
# ]
# [autoreload of numpy.core._methods failed: Traceback (most recent call last):
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py", line 16, in <module>
#     from numpy.compat import pickle, os_fspath, contextlib_nullcontext
# ImportError: cannot import name 'pickle' from 'numpy.compat' (/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/numpy/compat/__init__.py)
# ]
# [autoreload of numpy.core._add_newdocs failed: Traceback (most recent call last):
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/numpy/core/_add_newdocs.py", line 6839, in <module>
#     """.format(ftype=float_name)))
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/numpy/core/function_base.py", line 467, in add_newdoc
#     _add_docstring(getattr(new, doc[0]), doc[1].strip())
# AttributeError: type object 'numpy.float16' has no attribute 'as_integer_ratio'
# ]
# [autoreload of numpy.lib failed: Traceback (most recent call last):
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/numpy/lib/__init__.py", line 32, in <module>
#     __all__ += type_check.__all__
# NameError: name 'type_check' is not defined
# ]
# [autoreload of numpy.matrixlib failed: Traceback (most recent call last):
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/numpy/matrixlib/__init__.py", line 8, in <module>
#     __all__ = defmatrix.__all__
# NameError: name 'defmatrix' is not defined
# ]
# [autoreload of numpy.lib.npyio failed: Traceback (most recent call last):
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py", line 26, in <module>
#     from numpy.compat import (
# ImportError: cannot import name 'pickle' from 'numpy.compat' (/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/numpy/compat/__init__.py)
# ]
# [autoreload of numpy.lib.format failed: Traceback (most recent call last):
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/numpy/lib/format.py", line 171, in <module>
#     from numpy.compat import (
# ImportError: cannot import name 'pickle' from 'numpy.compat' (/ccs/home/hzfmer/file_back/programs/rhea/anaconda3/lib/python3.7/site-packages/numpy/compat/__init__.py)
# ]

# %%
#v1 = C.read_syn(40, 40, iz=1)
#v2 = C.read_syn(20, 20, iz=1)
#v1 = C.preproc_vel(v1)
#v2 = C.preproc_vel(v2)
plt.plot(v1.dt * np.arange(len(v1.x)), v1.x)
plt.plot(v2.dt * np.arange(len(v2.x)), v2.x + np.max(v1.x))
# plt.plot(v2.dt * np.arange(len(v2.x)), v1.x - v2.x)
print(np.max(v1.x - v2.x) / np.max(v1.x))
# Out:
# 0.9928415409635133

# %%
#sm_ref = calculate_smoothing_matrix(fv.f, normalize=True)
res = comp_TTF(C, 40, 40, 39, 12, smoother=sm_ref)
plt.loglog(res.f, res.ttf)
plt.xlim(0.5, 10)
plt.grid('on', which='both')
# Out:
# ix=0, iy=1, iz=0
# ix=0, iy=1, iz=2

# %%
plt.loglog(fv.f, apply_smoothing_matrix(fv.x, sm_ref, 1))
#plt.loglog(fv.f, fv.x)
plt.loglog(fv.f, fv.y)
plt.loglog(fv.f, fv.z)
plt.xlim(0.5, 10)
# Out:
# (0.5, 10)

# %%
vs = [140, 680, 1100, 1400, 1700]
h = [5, 92.5, 195, 472.5]
h1 = [7.5, 92.5, 195, 472.5]
f = np.arange(0, 10.001, 0.01)
theta = 0
amp = SH1D(vs, h, f)
amp1 = SH1D(vs, h1, f)
print(amp[::250])
plt.loglog(f, amp, label='amp')
plt.loglog(f, amp1, label='amp1')
plt.legend()
# Out:
# [1.         1.83863374 3.2638421  4.20228922 1.55766889]

# %%
data_dir = "/ccs/home/hzfmer/file_back/preevents"

bore_vs = np.array([220, 560, 1700, 3000])
bore_vp = np.array([1500, 2000, 2800, 5200])
bore_ro = np.array([2100, 2350, 2750, 2750])
bore_qs = 0.05 * bore_vs
bore_qp = 2 * bore_qs

h = [20, 44, 156]
#h = [12,44,56]
f = np.arange(0, 10.001, 0.01)
theta = 0
amp = SH1D(bore_vs, h, f)
amp1 = SH1D(bore_vs, h, f, rho=ro)
print(np.max(amp - amp1))
print(amp[::250])
plt.loglog(f, amp, label='amp')
plt.loglog(f, amp1, label='amp1')
plt.xlim(0.5, 10)
plt.legend()
# Out:
# 0.3112310287872999
# [1.         5.13101002 1.44726563 4.14223168 3.10978533]

# %%
nx, ny, nz = 80, 80, 100
dh = 4
h = [20, 64, 220]

vp = adjust_prop_1d(bore_vp, h, dh, np.zeros(nz,), 400)
vp = np.tile(vp, [nx, ny, 1]).swapaxes(0, 2)
vs = adjust_prop_1d(bore_vs, h, dh, np.zeros(nz,), 400)
vs = np.tile(vs, [nx, ny, 1]).swapaxes(0, 2)
ro = adjust_prop_1d(bore_ro, h, dh, np.zeros(nz,), 400)
ro = np.tile(ro, [nx, ny, 1]).swapaxes(0, 2)
qs = 0.05 * vs
qp = 2 * qs

dat = np.vstack(list(map(np.ravel, (vp, vs, ro, qp, qs)))).T.astype('f')
dat.tofile(Path('toy','mesh_toy_4m_1d.bin'))

print(amp[::250])
# Out:
# [1.         5.13101002 1.44726563 4.14223168 3.10978533]

# %%
aa = np.fromfile(Path('toy','mesh_toy_4m_1d.bin'), dtype='f').reshape(nz, ny, nx, 5)[:, :, 0, 1]

# %%
plt.imshow(aa, cmap='terrain')
print(aa.min(), aa.max())
# Out:
# 220.0 3000.0
