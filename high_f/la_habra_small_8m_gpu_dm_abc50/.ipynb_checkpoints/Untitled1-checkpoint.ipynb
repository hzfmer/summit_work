# %%
import numpy as np
import matplotlib as mpl
import matplotlib.colors as colors
import matplotlib.pyplot as plt
from scipy.signal import ricker
import seaborn as sns
sns.set(context='paper', style='whitegrid', )
from post_processing.la_habra import *

mpl.style.use('seaborn')
# %load_ext autoreload
# %autoreload 2

# %%
def write_mesh(nx, ny, nz, vp, vs, rho, fmesh):
    _vp = vp * np.ones((ny, nx), dtype='float32')
    _vs = vs * np.ones((ny, nx), dtype='float32')
    _rho = rho * np.ones((ny, nx), dtype='float32')
    with open(fmesh, 'wb') as fid:
        for _ in range(nz):
            mesh = np.dstack((_vp, _vs, _rho))
            mesh.tofile(fid)

# %%
def read_slice(it, bgx, skpx, endx, bgy, skpy, endy, bgz, skpz, endz, ix=0, iy=0, iz=0, model="", case="", block=0, comp="X"):
    '''Read wave field snapshot
    Input:
        it: time step to read
        mx, my: Surface 2D dimensions
        model: the name of the model
        case: different cases of a model, if exists
    '''
    tmax, dt, tskip, wstep, _ = read_params(model)
    ix, iy, iz = ix - 1, iy - 1, iz - 1  # convert to 0-indexed
    nt = int(tmax / dt)
    rx = np.arange(bgx, endx + 1, skpx)
    ry = np.arange(bgy, endy + 1, skpy)
    rz = np.arange(bgz, endz + 1, skpz)
    mx, my, mz = len(rx), len(ry), len(rz)
    print(f"\nShape of velocity output: ({mx}, {my}, {mz})")
    model = Path(model, "output_sfc" if not case else f"output_sfc_{case}")
    fnum = int(np.ceil((it + 1) / wstep) * wstep * tskip)
    print(f'\r{it} / {nt}, t = {dt * it}s, f_suffix={fnum}', end="\r", flush=True)
    v = np.fromfile(f'{model}/S{comp}_{block}_{fnum:07d}', dtype='float32',
                   count=mz * my * mx, offset=it * mx * my * mz * 4).reshape(mz, my, mx)
    # v = np.fromfile(f'{model}/S{comp}_{block}_{fnum:07d}', dtype='float32').reshape(-1, mz, my, mx)
    idx = np.where(np.isnan(v))
    if np.isnan(v).any():
        print(f"\n{len(idx[0])} NANs founded\n")
                   
    if iy > 0:
        v = v[:, iy, :]
        print(f'\nThe y_index is: {ry[iy]} / {endy}, Vmax = {np.max(v)}')
    elif ix >= 0:
        v = v[:, :, ix]
        print(f'\nThe x_index is: {rx[ix]} / {endx}, Vmax = {np.max(v)}')
    elif iz >= 0:
        v = v[iz, :, :]
        print(f'\nThe x_index is: {rz[iz]} / {endz}, Vmax = {np.max(v)}')
    return v.copy(), idx, dt

# %% [markdown]
# ## Model set up

# %% [markdown]
# ### Mesh

# %%
nx, ny, nz, mz = 900, 600, 300, 200
vp, vs, rho = 3600, 2500, 2500
dh = 30
dt = 0.003
print(f'dt < {dh / vp / 2}')

# write_mesh(nx, ny, nz, vp, vs, rho, 'homo_2layer_point/mesh_0')
# write_mesh(nx // 3, ny // 3, mz, vp, vs, rho, 'homo_2layer_point/mesh_1')


## Topo
# pad = 8
# height = 50
# header = np.array([nx, ny, pad], dtype='int32')
# topo = height * np.ones((nx + 2 * pad, ny + 2 * pad), dtype='float32')
# with open('homo_2layer_point/topography.bin', 'wb') as fid:
#     header.tofile(fid)
#     topo.tofile(fid)
# Out:
# dt < 0.004166666666666667

# %% [markdown]
# ### Source

# %%
nt = 1000
M0 = 1e15
src = np.zeros((nt, 6))
src[:, 0] = M0 * ricker(nt, 1)
src[:, 1] = M0 * ricker(nt, 1)
src[:, 2] = M0 * ricker(nt, 1)

with open('homo_2layer_point/source_0', 'wb') as fid:
    idx = np.array([nx // 2, ny // 2, nz // 2], dtype='int32')
    fid.write(idx)
    fid.write(src.astype('float32'))
    
with open('homo_2layer_point/source_1', 'wb') as fid:
    idx = np.array([nx // 6, ny // 6, mz // 2], dtype='int32')
    fid.write(idx)
    fid.write(src.astype('float32'))

# %% [markdown]
# ## Snapshot comparison

# %% [markdown]
# ### awp_topo, topo on

# %% [markdown]
# #### X-Z plane

# %%
it = 160
dt = 0.03
dh = 30
bgx, skpx, endx = 1, 4, 900
bgy, skpy, endy = 1, 3, 600
bgz, skpz, endz = 1, 3, 300

dh2 = 90
bgx2, skpx2, endx2 = 1, 2, 300
bgy2, skpy2, endy2 = 1, 2, 200
bgz2, skpz2, endz2 = 1, 2, 200

v, idx, _ = read_slice(it, bgx, skpx, endx, bgy, skpy, endy, bgz, skpz, endz,
                       iy=101, block=0, model='homo_2layer_point_flat')
v2, idx, _ = read_slice(it, bgx2, skpx2, endx2, bgy2, skpy2, endy2, bgz2, skpz2, endz2,
                        iy=51, block=1, model='homo_2layer_point_flat')
vmin, vmax = min(np.min(v), np.min(v2)), max(np.max(v), np.max(v2))

fig, ax = plt.subplots(dpi=200)
im = ax.pcolormesh(np.arange(bgx, endx + 1, skpx) * dh,
                   np.arange(bgz, endz + 1, skpz) * dh,
                   v, vmin=vmin, vmax=vmax,
                   #cmap='bwr')
                   norm=colors.SymLogNorm(linthresh=1e-4), cmap='bwr')
im2 = ax.pcolormesh(np.arange(bgx2, endx2 + 1, skpx2) * dh2,
                    nz * dh + np.arange(bgz2, endz2 + 1, skpz2) * dh2,
                    v2, vmin=vmin, vmax=vmax,
                    #cmap='bwr')
                    norm=colors.SymLogNorm(linthresh=1e-4), cmap='bwr')
ax.set_aspect('equal')
ax.invert_yaxis()
ax.scatter(nx // 2 * dh, 100 * dh, 150, color='g', marker='*')
ax.axvline(nx // 3 * dh, linestyle=':', linewidth=0.8, color='gray')
ax.axvline(nx * 2 // 3 * dh, linestyle=':', linewidth=0.8, color='gray')
ax.set(xlabel='X (m)', ylabel='Z (m)', title=f'T = {it * dt:.1f}s')
cbar = plt.colorbar(im, ax=ax)
cbar.set_label('V (m/s)')
# Out:
# Shape of velocity output: (225, 200, 100)
# 160 / 300, t = 4.8s, f_suffix=3000
# The y_index is: 301 / 600, Vmax = 67498.546875
#
# Shape of velocity output: (150, 100, 100)
# 160 / 300, t = 4.8s, f_suffix=3000
# The y_index is: 101 / 200, Vmax = 4967.1337890625

# %% [markdown]
# #### Y-Z plane

# %%
it = 70
dt = 0.03
dh = 30
bgx, skpx, endx = 1, 4, 900
bgy, skpy, endy = 1, 3, 600
bgz, skpz, endz = 1, 3, 300

dh2 = 90
bgx2, skpx2, endx2 = 1, 2, 300
bgy2, skpy2, endy2 = 1, 2, 200
bgz2, skpz2, endz2 = 1, 2, 200

v, idx, _ = read_slice(it, bgx, skpx, endx, bgy, skpy, endy, bgz, skpz, endz,
                       ix=113, block=0, model='homo_2layer_point_flat')
v2, idx, _ = read_slice(it, bgx2, skpx2, endx2, bgy2, skpy2, endy2, bgz2, skpz2, endz2,
                        ix=75, block=1, model='homo_2layer_point_flat')
vmin, vmax = min(np.min(v), np.min(v2)), max(np.max(v), np.max(v2))

fig, ax = plt.subplots(dpi=200)
im = ax.pcolormesh(np.arange(bgy, endy + 1, skpy) * dh,
                   np.arange(bgz, endz + 1, skpz) * dh,
                   v, vmin=vmin, vmax=vmax,
                   #cmap='bwr')
                   norm=colors.SymLogNorm(linthresh=1e-4), cmap='bwr')
im2 = ax.pcolormesh(np.arange(bgy2, endy2 + 1, skpy2) * dh2,
                    nz * dh + np.arange(bgz2, endz2 + 1, skpz2) * dh2,
                    v2, vmin=vmin, vmax=vmax,
                    #cmap='bwr')
                    norm=colors.SymLogNorm(linthresh=1e-4), cmap='bwr')
ax.set_aspect('equal')
ax.invert_yaxis()
ax.scatter(ny // 2 * dh, 100 * dh, 150, color='g', marker='*')
ax.axvline(ny // 2 * dh, linestyle=':', linewidth=0.8, color='gray')
ax.set(xlabel='Y (m)', ylabel='Z (m)', title=f'T = {it * dt:.1f}s')
cbar = plt.colorbar(im, ax=ax)
cbar.set_label('V (m/s)')
# Out:
# Shape of velocity output: (225, 200, 100)
# 70 / 300, t = 2.1s, f_suffix=3000
# The x_index is: 449 / 900, Vmax = 0.024146845564246178
#
# Shape of velocity output: (150, 100, 100)
# 70 / 300, t = 2.1s, f_suffix=3000
# The x_index is: 149 / 300, Vmax = 0.0

# %% [markdown]
# #### X-Y plane

# %%
it = 160
dt = 0.03
dh = 30
bgx, skpx, endx = 1, 4, 900
bgy, skpy, endy = 1, 3, 600
bgz, skpz, endz = 1, 3, 300

dh2 = 90
bgx2, skpx2, endx2 = 1, 2, 300
bgy2, skpy2, endy2 = 1, 2, 200
bgz2, skpz2, endz2 = 1, 2, 200

v, idx, _ = read_slice(it, bgx, skpx, endx, bgy, skpy, endy, bgz, skpz, endz,
                       iz=34, block=0, model='homo_2layer_point_flat')
v2, idx, _ = read_slice(it, bgx2, skpx2, endx2, bgy2, skpy2, endy2, bgz2, skpz2, endz2,
                        iz=1, block=1, model='homo_2layer_point_flat')

fig, ax = plt.subplots(dpi=200)
vmin, vmax = min(np.min(v), np.min(v2)), max(np.max(v), np.max(v2))
im = ax.pcolormesh(np.arange(bgx, endx + 1, skpx) * dh,
                   np.arange(bgy, endy + 1, skpy) * dh,
                   v, vmin=vmin, vmax=vmax,
                   #cmap='bwr')
                   norm=colors.SymLogNorm(linthresh=1e-4), cmap='bwr')
ax.set_aspect('equal')
ax.invert_yaxis()
ax.scatter(nx // 2 * dh, ny // 2 * dh, 150, color='g', marker='*')
ax.axvline(nx // 3 * dh, linestyle=':', linewidth=0.8, color='gray')
ax.axvline(nx * 2 // 3 * dh, linestyle=':', linewidth=0.8, color='gray')
ax.axhline(ny // 2 * dh, linestyle=':', linewidth=0.8, color='gray')
ax.set(xlabel='X (m)', ylabel='Y (m)', title=f'T = {it * dt:.1f}s')
cbar = plt.colorbar(im, ax=ax)
cbar.set_label('V (m/s)')
# Out:
# Shape of velocity output: (225, 200, 100)
# 160 / 300, t = 4.8s, f_suffix=3000
# The x_index is: 100 / 300, Vmax = 0.001965111820027232
#
# Shape of velocity output: (150, 100, 100)
# 160 / 300, t = 4.8s, f_suffix=3000
# The x_index is: 1 / 200, Vmax = 8218.849609375

# %% [markdown]
# ### awp-topo, topo off

# %% [markdown]
# #### X-Z plane

# %%
it = 70
dt = 0.03
dh = 30
bgx, skpx, endx = 1, 4, 900
bgy, skpy, endy = 1, 3, 600
bgz, skpz, endz = 1, 3, 300

dh2 = 90
bgx2, skpx2, endx2 = 1, 2, 300
bgy2, skpy2, endy2 = 1, 2, 200
bgz2, skpz2, endz2 = 1, 2, 200

v, idx, _ = read_slice(it, bgx, skpx, endx, bgy, skpy, endy, bgz, skpz, endz,
                       iy=101, block=0, model='homo_2layer_point_flat', case='notp')
v2, idx, _ = read_slice(it, bgx2, skpx2, endx2, bgy2, skpy2, endy2, bgz2, skpz2, endz2,
                        iy=51, block=1, model='homo_2layer_point_flat', case='notp')
vmin, vmax = min(np.min(v), np.min(v2)), max(np.max(v), np.max(v2))

fig, ax = plt.subplots(dpi=200)
im = ax.pcolormesh(np.arange(bgx, endx + 1, skpx) * dh,
                   np.arange(bgz, endz + 1, skpz) * dh,
                   v, vmin=vmin, vmax=vmax,
                   #cmap='bwr')
                   norm=colors.SymLogNorm(linthresh=1e-4), cmap='bwr')
im2 = ax.pcolormesh(np.arange(bgx2, endx2 + 1, skpx2) * dh2,
                    nz * dh + np.arange(bgz2, endz2 + 1, skpz2) * dh2,
                    v2, vmin=vmin, vmax=vmax,
                    #cmap='bwr')
                    norm=colors.SymLogNorm(linthresh=1e-4), cmap='bwr')
ax.set_aspect('equal')
ax.invert_yaxis()
ax.scatter(nx // 2 * dh, 100 * dh, 150, color='g', marker='*')
ax.axvline(nx // 3 * dh, linestyle=':', linewidth=0.8, color='gray')
ax.axvline(nx * 2 // 3 * dh, linestyle=':', linewidth=0.8, color='gray')
ax.set(xlabel='X (m)', ylabel='Z (m)', title=f'T = {it * dt:.1f}s')
cbar = plt.colorbar(im, ax=ax)
cbar.set_label('V (m/s)')
# Out:
# Shape of velocity output: (225, 200, 100)
# 70 / 300, t = 2.1s, f_suffix=3000
# The y_index is: 301 / 600, Vmax = 0.017289871349930763
#
# Shape of velocity output: (150, 100, 100)
# 70 / 300, t = 2.1s, f_suffix=3000
# The y_index is: 101 / 200, Vmax = 0.0

# %% [markdown]
# #### Y-Z plane

# %%
it = 70
dt = 0.03
dh = 30
bgx, skpx, endx = 1, 4, 900
bgy, skpy, endy = 1, 3, 600
bgz, skpz, endz = 1, 3, 300

dh2 = 90
bgx2, skpx2, endx2 = 1, 2, 300
bgy2, skpy2, endy2 = 1, 2, 200
bgz2, skpz2, endz2 = 1, 2, 200

v, idx, _ = read_slice(it, bgx, skpx, endx, bgy, skpy, endy, bgz, skpz, endz,
                       ix=113, block=0, model='homo_2layer_point_flat', case='notp')
v2, idx, _ = read_slice(it, bgx2, skpx2, endx2, bgy2, skpy2, endy2, bgz2, skpz2, endz2,
                        ix=75, block=1, model='homo_2layer_point_flat', case='notp')

fig, ax = plt.subplots(dpi=200)
vmin, vmax = min(np.min(v), np.min(v2)), max(np.max(v), np.max(v2))
im = ax.pcolormesh(np.arange(bgy, endy + 1, skpy) * dh,
                   np.arange(bgz, endz + 1, skpz) * dh,
                   v, vmin=vmin, vmax=vmax,
                   #cmap='bwr')
                   norm=colors.SymLogNorm(linthresh=1e-4), cmap='bwr')
im2 = ax.pcolormesh(np.arange(bgy2, endy2 + 1, skpy2) * dh2,
                    nz * dh + np.arange(bgz2, endz2 + 1, skpz2) * dh2,
                    v2, vmin=vmin, vmax=vmax,
                    #cmap='bwr')
                    norm=colors.SymLogNorm(linthresh=1e-4), cmap='bwr')
ax.set_aspect('equal')
ax.invert_yaxis()
ax.scatter(ny // 2 * dh, 100 * dh, 150, color='g', marker='*')
ax.axvline(ny // 2 * dh, linestyle=':', linewidth=0.8, color='gray')
ax.set(xlabel='Y (m)', ylabel='Z (m)', title=f'T = {it * dt:.1f}s')
cbar = plt.colorbar(im, ax=ax)
cbar.set_label('V (m/s)')
# Out:
# Shape of velocity output: (225, 200, 100)
# 70 / 300, t = 2.1s, f_suffix=3000
# The x_index is: 449 / 900, Vmax = 0.022399336099624634
#
# Shape of velocity output: (150, 100, 100)
# 70 / 300, t = 2.1s, f_suffix=3000
# The x_index is: 149 / 300, Vmax = 0.0

# %% [markdown]
# ### awp, topo off

# %% [markdown]
# #### X-Z plane

# %%
it = 70
dt = 0.03
dh = 30
bgx, skpx, endx = 1, 4, 900
bgy, skpy, endy = 1, 3, 600
bgz, skpz, endz = 1, 3, 300

dh2 = 90
bgx2, skpx2, endx2 = 1, 2, 300
bgy2, skpy2, endy2 = 1, 2, 200
bgz2, skpz2, endz2 = 1, 2, 200

v, idx, _ = read_slice(it, bgx, skpx, endx, bgy, skpy, endy, bgz, skpz, endz,
                       ix=113, block=0, model='homo_2layer_point')
v2, idx, _ = read_slice(it, bgx2, skpx2, endx2, bgy2, skpy2, endy2, bgz2, skpz2, endz2,
                        ix=75, block=1, model='homo_2layer_point')
vmin, vmax = min(np.min(v), np.min(v2)), max(np.max(v), np.max(v2))

fig, ax = plt.subplots(dpi=200)
im = ax.pcolormesh(np.arange(bgy, endy + 1, skpy) * dh,
                   np.arange(bgz, endz + 1, skpz) * dh,
                   v, vmin=vmin, vmax=vmax,
                   #cmap='bwr')
                   norm=colors.SymLogNorm(linthresh=1e-4), cmap='bwr')
im2 = ax.pcolormesh(np.arange(bgy2, endy2 + 1, skpy2) * dh2,
                    nz * dh + np.arange(bgz2, endz2 + 1, skpz2) * dh2,
                    v2, vmin=vmin, vmax=vmax,
                    #cmap='bwr')
                    norm=colors.SymLogNorm(linthresh=1e-4), cmap='bwr')
ax.set_aspect('equal')
ax.invert_yaxis()
#ax.scatter(ny // 2 * dh, 100 * dh, 150, color='g', marker='*')
ax.axvline(ny // 2 * dh, linestyle=':', linewidth=0.8, color='gray')
ax.set(xlabel='Y (m)', ylabel='Z (m)', title=f'T = {it * dt:.1f}s')
cbar = plt.colorbar(im, ax=ax)
cbar.set_label('V (m/s)')
# Out:
# Shape of velocity output: (225, 200, 100)
# 70 / 300, t = 2.1s, f_suffix=3000
# The x_index is: 449 / 900, Vmax = 0.018633462488651276
#
# Shape of velocity output: (150, 100, 100)
# 70 / 300, t = 2.1s, f_suffix=3000
# The x_index is: 149 / 300, Vmax = 0.0

# %% [markdown]
# #### Y-Z plane

# %%
it = 170
dt = 0.03
dh = 30
bgx, skpx, endx = 1, 4, 900
bgy, skpy, endy = 1, 3, 600
bgz, skpz, endz = 1, 3, 300

dh2 = 90
bgx2, skpx2, endx2 = 1, 2, 300
bgy2, skpy2, endy2 = 1, 2, 200
bgz2, skpz2, endz2 = 1, 2, 200

v, idx, _ = read_slice(it, bgx, skpx, endx, bgy, skpy, endy, bgz, skpz, endz,
                       ix=113, block=0, model='homo_2layer_point')
v2, idx, _ = read_slice(it, bgx2, skpx2, endx2, bgy2, skpy2, endy2, bgz2, skpz2, endz2,
                        ix=75, block=1, model='homo_2layer_point')
vmin, vmax = min(np.min(v), np.min(v2)), max(np.max(v), np.max(v2))

fig, ax = plt.subplots(dpi=200)
im = ax.pcolormesh(np.arange(bgy, endy + 1, skpy) * dh,
                   np.arange(bgz, endz + 1, skpz) * dh,
                   v, vmin=vmin, vmax=vmax,
                   cmap='bwr')
                   #norm=colors.SymLogNorm(linthresh=1e-4), cmap='bwr')
im2 = ax.pcolormesh(np.arange(bgy2, endy2 + 1, skpy2) * dh2,
                    nz * dh + np.arange(bgz2, endz2 + 1, skpz2) * dh2,
                    v2, vmin=vmin, vmax=vmax,
                    cmap='bwr')
                    #norm=colors.SymLogNorm(linthresh=1e-4), cmap='bwr')
ax.set_aspect('equal')
ax.invert_yaxis()
ax.scatter(ny // 2 * dh, 100 * dh, 150, color='g', marker='*')
ax.axvline(ny // 2 * dh, linestyle=':', linewidth=0.8, color='gray')
ax.set(xlabel='Y (m)', ylabel='Z (m)', title=f'T = {it * dt:.1f}s')
cbar = plt.colorbar(im, ax=ax)
cbar.set_label('V (m/s)')
# Out:
# Shape of velocity output: (225, 200, 100)
# 170 / 300, t = 5.1s, f_suffix=3000
# The x_index is: 449 / 900, Vmax = 0.001625629374757409
#
# Shape of velocity output: (150, 100, 100)
# 170 / 300, t = 5.1s, f_suffix=3000
# The x_index is: 149 / 300, Vmax = 1.2728969522868283e-05

# %% [markdown]
# ## Check

# %% [markdown]
# ### Source

# %%
s = np.fromfile('homo_2layer_point/source_0', dtype='float32', offset=12).reshape(-1, 6)
plt.plot(s[:, 0], label='XX')
plt.plot(s[:, 1], label='YY')
plt.plot(s[:, 2], label='ZZ')
plt.xlim(450, 550)
plt.legend()

# %%
ix, iy = 200, 200
vel = read_syn(ix, iy, mx, my, model='homo_2layer_point')
fig, ax = plt.subplots(dpi=200)
ax.plot(np.arange(len(vel['X'])) * vel['dt'], vel['X'])
ax.set(xlabel='Time (s)', ylabel='V (m/s)')
# Out:
# homo_2layer_point 0.03 10 300 1
# homo_2layer_point/output_sfc/SX_0_0003000
# homo_2layer_point/output_sfc/SY_0_0003000
# homo_2layer_point/output_sfc/SZ_0_0003000
# [Text(0,0.5,'V (m/s)'), Text(0.5,0,'Time (s)')]
